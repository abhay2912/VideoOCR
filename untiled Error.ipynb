# %%
import cv2
import pytesseract
import pandas as pd

# %%
# Initialize Tesseract OCR (make sure you have Tesseract installed)
pytesseract.pytesseract.tesseract_cmd = r'C:\Users\user\OneDrive\Desktop\AI&ML\videoOCR\tesseract-ocr.exe'

# Load the video
video_path = 'video.mp4'
cap = cv2.VideoCapture(video_path)

# Create an empty DataFrame to store extracted messages
# data = {'Person': [], 'Message': []}

# Output folder for saving frames as images
output_folder = 'frames/'

# Open the video file
cap = cv2.VideoCapture(video_path)

# Create the output folder if it doesn't exist
import os
os.makedirs(output_folder, exist_ok=True)

# Initialize frame counter
frame_counter = 0

while True:
    # Read a frame from the video
    ret, frame = cap.read()
    
    # Break the loop if we reach the end of the video
    if not ret:
        break
    
    # Save the frame as an image
    frame_filename = f"{output_folder}frame_{frame_counter:04d}.png"
    cv2.imwrite(frame_filename, frame)
    
    # Perform OCR on the saved frame
    frame_image = cv2.imread(frame_filename)
    frame_text = pytesseract.image_to_string(frame_image)
    
    # Print or store the extracted text as needed
    print(f"Frame {frame_counter}: {frame_text.strip()}")
    
    frame_counter += 1

# Release the video capture object
cap.release()

print(f"Frames saved in '{output_folder}'")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [4], in <cell line: 24>()
#      36 # Perform OCR on the saved frame
#      37 frame_image = cv2.imread(frame_filename)
# ---> 38 frame_text = pytesseract.image_to_string(frame_image)
#      40 # Print or store the extracted text as needed
#      41 print(f"Frame {frame_counter}: {frame_text.strip()}")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pytesseract\pytesseract.py:423, in image_to_string(image, lang, config, nice, output_type, timeout)
#     418 """
#     419 Returns the result of a Tesseract OCR run on the provided image to string
#     420 """
#     421 args = [image, 'txt', lang, config, nice, timeout]
# --> 423 return {
#     424     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     425     Output.DICT: lambda: {'text': run_and_get_output(*args)},
# ...

# %%
import cv2
import pytesseract

# Load the video file
video_file = "video.mp4"

# Initialize the video capture object
cap = cv2.VideoCapture(video_file)

# Create an output file to store the extracted text
output_file = "text.txt"

# Iterate over the video frames
while True:
    ret, frame = cap.read()

    # Extract the text from the frame
    text = pytesseract.image_to_string(frame)

    # Write the text to the output file
    with open(output_file, "a") as f:
        f.write(text)

    # Check if the end of the video has been reached
    if not ret:
        break

# Close the video capture object
cap.release()

# %%
def extract_text_and_speakers(chat_window):
    """
    Extracts the text and identifies the speakers from the chat window.

    Args:
        chat_window: The chat window to process.

    Returns:
        A tuple of the text and the speakers.
    """

    text = ""
    speakers = []

    # Convert the image to RGB.
    rgb_image = cv2.cvtColor(chat_window, cv2.COLOR_BGR2RGB)

    # Find all the text lines in the chat window.
    text_lines = cv2.findContours(
        rgb_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
    )[-1]

    # For each text line, extract the text and identify the speaker.
    for text_line in text_lines:
        # The text line must be at least a certain size.
        if cv2.contourArea(text_line) > chat_window_width * chat_window_height / 100:
            # The text line must be wider than it is tall.
            if cv2.contourArea(cv2.rotate(text_line, 180)) < cv2.contourArea(text_line):
                # Extract the text from the text line.
                text_bounding_box = cv2.boundingRect(text_line)
                text = cv2.putText(
                    chat_window,
                    cv2.imread("./chat_bubble.png"),
                    (text_bounding_box[0], text_bounding_box[1] - 10),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.6,
                    (0, 0, 0),
                    1,
                    cv2.LINE_AA,
                )

                # Identify the speaker of the text line using a more sophisticated algorithm.
                speakers.append(speaker_identification_algorithm(text_line))

    return text, speakers


import cv2
import numpy as np
import pandas as pd

# Define the dimensions of the chat window
chat_window_width = 640
chat_window_height = 480

# Initialize the Excel spreadsheet
df = pd.DataFrame(columns=["Person", "Message"])

# Read the video file
video_file = "video.mp4"
cap = cv2.VideoCapture(video_file)

# Loop over the frames of the video
while True:
    ret, frame = cap.read()

    # Find the chat windows in the frame using a more robust text detection algorithm
    chat_windows = cv2.findContours(
        cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
    )[-1]

    # For each chat window, extract the text and identify the speakers using a more sophisticated speaker identification algorithm
    for chat_window in chat_windows:
        text, speakers = extract_text_and_speakers(chat_window)

        # Identify the sender and receiver of the conversation
        sender = speakers[0]
        receiver = speakers[-1]

        # Add the conversation to the Excel spreadsheet in a more structured format
        df.loc[len(df)] = {"Person": sender, "Message": text}

    # Write the Excel spreadsheet to disk
    df.to_json("conversations.json")

    # Display the frame
    cv2.imshow("Frame", frame)
    key = cv2.waitKey(1)

    # If the user presses `q`, stop the loop
    if key == ord("q"):
        break

# Release the resources
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [5], in <cell line: 64>()
#      72 # For each chat window, extract the text and identify the speakers using a more sophisticated speaker identification algorithm
#      73 for chat_window in chat_windows:
# ---> 74     text, speakers = extract_text_and_speakers(chat_window)
#      76     # Identify the sender and receiver of the conversation
#      77     sender = speakers[0]
#
# Input In [5], in extract_text_and_speakers(chat_window)
#      13 speakers = []
#      15 # Convert the image to RGB.
# ---> 16 rgb_image = cv2.cvtColor(chat_window, cv2.COLOR_BGR2RGB)
#      18 # Find all the text lines in the chat window.
#      19 text_lines = cv2.findContours(
#      20     rgb_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
#      21 )[-1]
#
# ...
